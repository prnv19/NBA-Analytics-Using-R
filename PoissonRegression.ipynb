# %%
set.seed(123)

norm_data = read.csv("Data/Processed/nba_normal_scorers_filtered.csv")
# norm_data = norm_data[sample(nrow(norm_data), 900), ]

norm_data = subset(norm_data, select = -c(Player, Team, Pos, Awards, AllStarSelection, Rk))

norm_data$PTS = as.integer(norm_data$PTS)

norm_data = na.omit(norm_data)

n = floor(0.8 * nrow(norm_data))
index = sample(seq_len(nrow(norm_data)), size = n)

norm.train = norm_data[index, ]
norm.test = norm_data[-index, ]

head(norm.train)
summary(norm.train)
# Out:
#      Age G  GS MP   FG  FGA FG.   X3P X3PA X3P.  ⋯ DRB TRB AST STL BLK TOV PF
# 511  32  55  7 17.3 2.2 5.2 0.433 0.7 1.5  0.439 ⋯ 1.3 1.6 2.4 0.6 0.2 1.2 1.0
# 568  27  29  4 10.9 1.9 3.9 0.496 0.1 0.5  0.200 ⋯ 1.7 2.7 0.1 0.1 0.5 0.5 1.8
# 209  24  37 12 24.5 1.8 4.4 0.414 0.6 1.9  0.324 ⋯ 1.8 2.3 2.1 1.1 0.1 0.8 1.6
# 645  20  15  1  5.6 0.7 1.8 0.407 0.3 0.7  0.400 ⋯ 0.7 1.1 0.3 0.2 0.3 0.3 0.7
# 229  25  42  5 13.5 1.3 3.2 0.406 0.9 2.6  0.351 ⋯ 1.7 2.6 0.4 0.1 0.5 0.2 1.1
# 1203 32  68 40 24.4 3.9 9.4 0.411 1.4 4.2  0.333 ⋯ 1.8 2.1 3.4 0.7 0.1 1.7 1.7
#      PTS Year Salary
# 511   6  2021  4110433
# 568   4  2021  2294633
# 209   4  2020  4906243
# 645   1  2021  1849950
# 229   3  2020   881609
# 1203 10  2023 12147949
#       Age              G               GS              MP
#  Min.   :19.00   Min.   : 1.00   Min.   : 0.00   Min.   : 2.00
#  1st Qu.:22.00   1st Qu.:24.00   1st Qu.: 0.00   1st Qu.:12.03
#  Median :24.00   Median :48.00   Median : 5.00   Median :17.95
#  Mean   :25.46   Mean   :44.33   Mean   :18.51   Mean   :18.79
#  3rd Qu.:28.00   3rd Qu.:65.00   3rd Qu.:31.00   3rd Qu.:25.80
#  Max.   :43.00   Max.   :84.00   Max.   :83.00   Max.   :43.50
#        FG             FGA              FG.              X3P
#  Min.   :0.000   Min.   : 0.500   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:1.400   1st Qu.: 3.400   1st Qu.:0.3990   1st Qu.:0.3000
#  Median :2.500   Median : 5.600   Median :0.4400   Median :0.7000
#  Mean   :2.947   Mean   : 6.499   Mean   :0.4456   Mean   :0.9073
#  3rd Qu.:4.000   3rd Qu.: 8.600   3rd Qu.:0.4920   3rd Qu.:1.3000
#  Max.   :8.800   Max.   :19.400   Max.   :0.7470   Max.   :4.0000
#       X3PA            X3P.             X2P             X2PA
#  Min.   :0.000   Min.   :0.0000   Min.   :0.000   Min.   : 0.100
#  1st Qu.:1.025   1st Qu.:0.2730   1st Qu.:0.900   1st Qu.: 1.700
#  Median :2.300   Median :0.3330   Median :1.600   Median : 3.100
#  Mean   :2.621   Mean   :0.3087   Mean   :2.041   Mean   : 3.881
#  3rd Qu.:3.800   3rd Qu.:0.3750   3rd Qu.:2.900   3rd Qu.: 5.275
#  Max.   :9.900   Max.   :1.0000   Max.   :8.500   Max.   :14.900
#       X2P.             eFG.              FT             FTA
#  Min.   :0.0000   Min.   :0.0000   Min.   :0.000   Min.   :0.000
#  1st Qu.:0.4652   1st Qu.:0.4770   1st Qu.:0.400   1st Qu.:0.600
#  Median :0.5185   Median :0.5210   Median :0.900   Median :1.200
#  Mean   :0.5168   Mean   :0.5138   Mean   :1.169   Mean   :1.528
#  3rd Qu.:0.5780   3rd Qu.:0.5640   3rd Qu.:1.600   3rd Qu.:2.100
#  Max.   :1.0000   Max.   :0.8890   Max.   :7.900   Max.   :8.900
#       FT.              ORB              DRB             TRB
#  Min.   :0.0000   Min.   :0.0000   Min.   : 0.00   Min.   : 0.00
#  1st Qu.:0.6803   1st Qu.:0.3000   1st Qu.: 1.40   1st Qu.: 1.80
#  Median :0.7720   Median :0.6000   Median : 2.30   Median : 3.00
#  Mean   :0.7464   Mean   :0.8224   Mean   : 2.55   Mean   : 3.37
#  3rd Qu.:0.8380   3rd Qu.:1.1000   3rd Qu.: 3.40   3rd Qu.: 4.30
#  Max.   :1.0000   Max.   :5.1000   Max.   :11.00   Max.   :15.20
#       AST              STL              BLK              TOV
#  Min.   : 0.000   Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.: 0.700   1st Qu.:0.3000   1st Qu.:0.1000   1st Qu.:0.5000
#  Median : 1.300   Median :0.5000   Median :0.3000   Median :0.8000
#  Mean   : 1.843   Mean   :0.5856   Mean   :0.3825   Mean   :0.9925
#  3rd Qu.: 2.400   3rd Qu.:0.8000   3rd Qu.:0.5000   3rd Qu.:1.3000
#  Max.   :10.800   Max.   :2.0000   Max.   :3.6000   Max.   :4.0000
#        PF             PTS             Year          Salary
#  Min.   :0.000   Min.   : 0.00   Min.   :2020   Min.   :    6201
#  1st Qu.:1.100   1st Qu.: 3.00   1st Qu.:2021   1st Qu.: 1735070
#  Median :1.600   Median : 6.00   Median :2022   Median : 3081038
#  Mean   :1.618   Mean   : 7.55   Mean   :2022   Mean   : 7359784
#  3rd Qu.:2.100   3rd Qu.:10.00   3rd Qu.:2023   3rd Qu.: 9551517
#  Max.   :5.000   Max.   :23.00   Max.   :2024   Max.   :51238730

# %%
mod2_pois_exposure = glm(PTS ~ FGA + X3PA + FTA + TOV + AST + offset(log(MP)), 
                         family = poisson(link = "log"), 
                         data = norm.train)

summary(mod2_pois_exposure)
# Out:
# Call:
# glm(formula = PTS ~ FGA + X3PA + FTA + TOV + AST + offset(log(MP)),
#     family = poisson(link = "log"), data = norm.train)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.392967   0.024766 -56.244  < 2e-16 ***
# FGA          0.053565   0.005794   9.245  < 2e-16 ***
# X3PA        -0.004142   0.007851  -0.528  0.59777
# FTA          0.056398   0.011750   4.800 1.59e-06 ***
# TOV         -0.015083   0.028445  -0.530  0.59594
# AST         -0.028856   0.008938  -3.229  0.00124 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 963.44  on 1169  degrees of freedom
# Residual deviance: 356.44  on 1164  degrees of freedom
# AIC: 4583.9
#
# Number of Fisher Scoring iterations: 4

# %%
mod3_pois_exposure = glm(PTS ~ FGA + X3PA + FTA + AST + offset(log(MP)), 
                         family = poisson(link = "log"), 
                         data = norm.train)

summary(mod3_pois_exposure)
# Out:
# Call:
# glm(formula = PTS ~ FGA + X3PA + FTA + AST + offset(log(MP)),
#     family = poisson(link = "log"), data = norm.train)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.395637   0.024254 -57.543  < 2e-16 ***
# FGA          0.052615   0.005515   9.540  < 2e-16 ***
# X3PA        -0.003528   0.007768  -0.454     0.65
# FTA          0.054528   0.011216   4.862 1.16e-06 ***
# AST         -0.031620   0.007270  -4.350 1.36e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 963.44  on 1169  degrees of freedom
# Residual deviance: 356.72  on 1165  degrees of freedom
# AIC: 4582.2
#
# Number of Fisher Scoring iterations: 4
